# %% [markdown]
# # Minggu 2 — Pandas: baca data & inspeksi
#
# **Sub-CPMK:** **P2**
#
# Dataset kecil sintetis + pola membaca CSV.

# %%
import pandas as pd

df = pd.DataFrame({
    "nim": ["001", "002", "003"],
    "nilai": [78, 85, 90],
    "kelas": ["A", "B", "A"],
})
df.head()

# %%
df.info()
df.describe(include='all')

# %% [markdown]
# ## Latihan (TODO)
# - Muat file CSV/Excel Anda sendiri dengan `pd.read_csv` atau `read_excel`.

# %%
pass  # TODO: pd.read_csv('nama_file.csv')
