# %% [markdown]
# # Minggu 13 — Narasi di notebook & ringkasan eksekutif
#
# **Sub-CPMK:** **P10**
#
# ## Struktur yang disarankan
# 1. **Konteks bisnis / pertanyaan**
# 2. **Data & keterbatasan**
# 3. **Metode singkat**
# 4. **Temuan utama (bullet)**
# 5. **Rekomendasi / next step**

# %% [markdown]
# **Template ringkasan.** String multi-baris ini meniru kerangka Markdown eksekutif; di praktikum, salin isi ke **sel Markdown** sungguhan dan ganti bullet dengan temuan numerik/plot dari notebook analisis Anda.

# %%
RINGKASAN = '''
## Ringkasan eksekutif (TODO isi)
- Pertanyaan:
- Data:
- Model / metrik:
- Kesimpulan:
'''
print(RINGKASAN)  # contoh: cetak kerangka; versi final sebaiknya di sel Markdown, bukan string Python

# %% [markdown]
# ## Latihan
# - Lengkapi template Markdown di atas untuk proyek Anda.
