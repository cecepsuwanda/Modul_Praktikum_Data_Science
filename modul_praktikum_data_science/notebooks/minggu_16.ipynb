# %% [markdown]
# ## Struktur presentasi (8–10 menit)
# 1. Masalah dan motivasi (30–60 dtk)
# 2. Data dan prapemrosesan ringkas (60 dtk)
# 3. Model dan evaluasi (2–3 mnt)
# 4. Temuan utama dan rekomendasi (1–2 mnt)
# 5. Keterbatasan dan etika data (30 dtk)

# %% [markdown]
# **Outline presentasi.** Daftar `poin_presentasi` memetakan slide; `enumerate(..., 1)` memberi nomor urut mulai 1 untuk cetak yang rapi saat latihan demo.

# %%
# TODO: ringkaslah poin presentasi Anda (boleh ganti dengan print)
poin_presentasi = [
    "...",  # ganti dengan poin nyata: data, model, metrik, rekomendasi
]
for i, p in enumerate(poin_presentasi, start=1):  # start=1: nomor slide mulai 1
    print(i, p)

# %% [markdown]
# ## Refleksi etika (TODO)
# (Satu paragraf singkat.)

# %%
import os
for f in ["proyek_final.ipynb", "laporan.pdf"]:
    if os.path.exists(f):
        print(f, os.path.getsize(f) / 1024, "KB")
