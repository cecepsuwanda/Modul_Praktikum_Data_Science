# %% [markdown]
# # Minggu 16 — Presentasi & penyerahan akhir
#
# **Sub-CPMK:** **P10**
#
# ## Checklist penyerahan
# - Notebook utama + PDF/slide (jika diminta)
# - README singkat: cara menjalankan ulang
# - Atribusi data & referensi
# - Refleksi etika 3–5 kalimat

# %%
# TODO: ringkaslah poin presentasi Anda (boleh ganti dengan print)
poin_presentasi = [
    "...",
]
for i, p in enumerate(poin_presentasi, 1):
    print(i, p)

# %% [markdown]
# ## Refleksi etika (TODO)
# (Satu paragraf singkat.)
