# %% [markdown]
# ## Lembar review (isi singkat)
# - **Reproduksi**: apakah Restart & Run All lulus tanpa intervensi?
# - **Narasi**: apakah setiap plot/kode punya konteks?
# - **Etika**: apakah sumber data dan lisensi lengkap?

# %% [markdown]
# **Reproduktifitas.** Mencetak versi `sklearn` dan `pandas` membantu rekan men-debug ketidakkocokan API; `RNG` mengingatkan memakai `random_state` konsisten di split dan model.

# %%
import sklearn
import pandas as pd
print("sklearn", sklearn.__version__)  # nomor versi scikit-learn di kernel ini
print("pandas", pd.__version__)
RNG = 42  # contoh benih acak terpusat untuk train_test_split / model
print("random_state contoh", RNG)

# %% [markdown]
# **Catatan review.** Ganti `pass` dengan ringkasan temuan peer review (sel gagal, dependensi, saran) atau tautan ke lembar review.

# %%
# Contoh isi requirements.txt (buat sebagai file terpisah jika diminta dosen)
# jupyter>=1.0
# numpy>=1.24
# pandas>=2.0
# matplotlib>=3.7
# seaborn>=0.12
# scikit-learn>=1.3
# openpyxl>=3.1

# %%
pass  # TODO: catatan review teman (contoh: sel X gagal karena paket Y belum terpasang)
