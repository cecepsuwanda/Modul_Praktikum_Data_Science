# %% [markdown]
# # Minggu 14 — Peer review & reproduktifitas
#
# **Sub-CPMK:** **P10**
#
# ## Checklist
# - Versi Python & paket utama (`pip freeze` selektif)
# - `random_state` konsisten
# - Urutan sel dapat **Restart & Run All**
# - Sumber data & lisensi terdokumentasi

# %%
import sklearn
import pandas as pd
print("sklearn", sklearn.__version__)
print("pandas", pd.__version__)
RNG = 42
print("random_state contoh", RNG)

# %% [markdown]
# ## Latihan (TODO)
# - Tukar notebook dengan teman; isi formulir review singkat di sel Markdown.

# %%
pass  # TODO: catatan review teman
