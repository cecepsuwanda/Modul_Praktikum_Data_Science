# %% [markdown]
# # Praktikum Data Science — Minggu 1
#
# **Topik (RPS):** Jupyter, kernel, Markdown; CRISP-DM ringkas; etika & lisensi data
# **Sub-CPMK:** **P1**
#
# ## Kemampuan akhir sesi
# Setelah sesi, Anda mampu:
# 1. Membuat notebook baru dan mengeksekusi sel Markdown serta sel kode Python.
# 2. Menjelaskan enam fase CRISP-DM secara ringkas dan mengaitkannya dengan satu studi kasus.
# 3. Mendokumentasikan sumber data, lisensi, dan batasan penggunaan di Markdown.
# 4. Menyimpan berkas `.ipynb` sesuai konvensi penamaan.
#
# ## Konsep kunci
# - **Sel Markdown** untuk narasi, **sel kode** untuk eksperimen.
# - **Kernel** adalah proses Python yang menjalankan kode. Nomor eksekusi sel menunjukkan urutan eksekusi terakhir.
# - Setelah banyak mengubah sel, lakukan **Restart Kernel & Run All** untuk memeriksa reproduktifitas.
#
# ## CRISP-DM (ringkas)
# Business Understanding → Data Understanding → Data Preparation → Modeling → Evaluation → Deployment.
#
# ## Etika & lisensi data
# Cantumkan **URL sumber** dan **lisensi** (mis. CC, domain publik, syarat Kaggle). Hindari mengunggah data yang berisi **PII** tanpa izin. Jika memakai data sintetis, tulis secara eksplisit bahwa data sintetis.

# %% [markdown]
# Sel berikut memeriksa **versi Python** dan **path interpreter** yang dipakai kernel (`sys.version`, `sys.executable`). Ini membantu memastikan lingkungan praktikum sesuai (misalnya Python 3.10+) sebelum menjalankan kode lain; jika path tidak sesuai harapan, periksa kernel yang dipilih di Jupyter/VS Code.

# %%
# %matplotlib inline  — magic Jupyter (hanya jika Anda membuat plot); baris ini boleh dihapus di minggu 1
import sys  # modul standar: informasi interpreter

print("Python", sys.version)  # versi lengkap interpreter yang menjalankan sel ini
print("Uji kernel: OK")  # jika baris ini tercetak, eksekusi sel berhasil

# %%
# Contoh struktur dokumentasi CRISP-DM ringkas (boleh disesuaikan)
crisp_dm = {
    "business_understanding": "Mengurangi churn pelanggan e-commerce",
    "data_understanding": "Dataset transaksi terbuka, cek missing",
    "data_prep": "Imputasi, encoding kategori",
    "modeling": "Klasifikasi churn dengan RandomForest",
    "evaluation": "F1-score, confusion matrix",
    "deployment": "Dashboard internal (di luar cakupan praktikum)",
}
for fase, catatan in crisp_dm.items():
    print(f"{fase}: {catatan}")

# %% [markdown]
# Sel berikut adalah **scaffold** latihan dokumentasi etika: ganti nilai `Sumber_data` agar memuat **URL sumber data**, **lisensi**, dan batas penggunaan (seperti contoh pada modul PDF minggu 1).

# %%
# TODO: ganti nilai di bawah sesuai dataset Anda
Sumber_data = {
    "url": "https://www.kaggle.com/datasets/...",
    "lisensi": "CC0 / sesuai halaman dataset",
    "tanggal_unduh": "2026-04-10",
    "catatan": "Tidak untuk komersial tanpa izin pemilik dataset.",
}

import json  # modul standar: serialisasi JSON
print(json.dumps(Sumber_data, indent=2, ensure_ascii=False))
