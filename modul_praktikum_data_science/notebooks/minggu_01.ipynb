# %% [markdown]
# # Praktikum Data Science — Minggu 1
#
# **Topik (RPS):** Jupyter, CRISP-DM ringkas, etika & lisensi data
# **Sub-CPMK:** **P1**
#
# ## Tujuan
# - Menjalankan notebook dan kernel Python.
# - Menyebut fase CRISP-DM secara singkat.
# - Menyadari lisensi/atribusi data dan privasi.
#
# ## CRISP-DM (ringkas)
# Pemahaman bisnis → pemahaman data → persiapan → pemodelan → evaluasi → deployment.
#
# ## Etika data
# Gunakan data sesuai lisensi; jangan menyebarkan PII tanpa izin; dokumentasikan sumber.

# %% [markdown]
# Sel berikut memeriksa **versi Python** dan **path interpreter** yang dipakai kernel (`sys.version`, `sys.executable`). Ini membantu memastikan lingkungan praktikum sesuai (misalnya Python 3.10+) sebelum menjalankan kode lain; jika path tidak sesuai harapan, periksa kernel yang dipilih di Jupyter/VS Code.

# %%
# %matplotlib inline  — magic Jupyter (hanya jika Anda membuat plot); baris ini boleh dihapus di minggu 1
import sys  # modul standar: informasi interpreter

print("Python", sys.version)  # versi lengkap interpreter yang menjalankan sel ini
print("Uji kernel: OK")  # jika baris ini tercetak, eksekusi sel berhasil

# %% [markdown]
# ## Latihan (TODO)
#
# Paragraf berikut dapat Anda tulis di sel Markdown baru atau diringkas di sel kode di bawahnya. Hubungkan jawaban dengan **etika data** (lisensi, PII, atribusi) seperti pada modul PDF minggu 1.
#
# - Tulis satu paragraf: sumber data yang akan dipakai dan lisensinya.

# %% [markdown]
# Sel berikut adalah **placeholder** untuk latihan dokumentasi etika: ganti `pass` dengan kode atau komentar yang merangkum **URL sumber data**, **lisensi**, dan batas penggunaan (seperti contoh `Sumber_data` + `json.dumps` pada modul PDF minggu 1). Menulis `pass` membuat sel tetap valid secara sintaks sementara Anda mengisi jawaban.

# %%
# TODO: cantumkan URL, lisensi, dan tanggal unduh (lihat modul bab 1 / sel Markdown latihan)
# Contoh: dict metadata lalu print(json.dumps(..., indent=2, ensure_ascii=False))
pass  # placeholder: hapus pass setelah Anda mengisi dokumentasi sumber data
